# %%
#Import Library
import pandas as pd

# %%
#Load CSV file
df = pd.read_csv("Forbes.csv")

# %%
df
# Out:
#       2022 Ranking                               Organization  \
# 0                1                         Berkshire Hathaway
# 1                2                                       ICBC
# 2                3   Saudi Arabian Oil Company (Saudi Aramco)
# 3                4                             JPMorgan Chase
# 4                5                    China Construction Bank
# ...            ...                                        ...
# 1994          1995                                     Aperam
# 1995          1995  Shenzhen Feima International Supply Chain
# 1996          1997                                       NMDC
# 1997          1997                 Sichuan Changhong Electric
# 1998          1999                         Satellite Chemical
#
#                           Industry        Country  Year Founded  \
# 0           Diversified Financials  United States          1939
# 1                          Banking          China          1984
# ...

# %%
#Q1:  Fetch data from paticular column as : row(1) , column(1) 
df.loc[1]
# Out:
# 2022 Ranking                     2
# Organization                  ICBC
# Industry                   Banking
# Country                      China
# Year Founded                  1984
# CEO                         Shu Gu
# Revenue (Billions)          208.13
# Profits (Billions)           54.03
# Assets (Billions)          5518.51
# Market Value (Billions)     214.42
# Total Employees             449296
# Name: 1, dtype: object

# %%
#Q2: Print length of rows
len(df)
# Out:
# 1999

# %%
# Q3: Print first 4 records of dataset  
df.head(4)
# Out:
#    2022 Ranking                              Organization  \
# 0             1                        Berkshire Hathaway
# 1             2                                      ICBC
# 2             3  Saudi Arabian Oil Company (Saudi Aramco)
# 3             4                            JPMorgan Chase
#
#                  Industry        Country  Year Founded  \
# 0  Diversified Financials  United States          1939
# 1                 Banking          China          1984
# 2    Oil & Gas Operations   Saudi Arabia          1933
# 3  Diversified Financials  United States          2000
#
#                         CEO  Revenue (Billions)  Profits (Billions)  \
# 0     Warren Edward Buffett              276.09               89.80
# 1                    Shu Gu              208.13               54.03
# 2  Amin bin Hasan Al-Nasser              400.38              105.36
# 3               Jamie Dimon              124.54               42.12
#
# ...

# %%
# Q3: Print last 4 records of dataset  
df.tail(4)
# Out:
#       2022 Ranking                               Organization  \
# 1995          1995  Shenzhen Feima International Supply Chain
# 1996          1997                                       NMDC
# 1997          1997                 Sichuan Changhong Electric
# 1998          1999                         Satellite Chemical
#
#                           Industry Country  Year Founded             CEO  \
# 1995  Business Services & Supplies   China          1998  Shan Min Huang
# 1996                     Materials   India          1958       Sumit Deb
# 1997             Consumer Durables   China          1988          Wei Li
# 1998                     Chemicals   China             0         No Data
#
#       Revenue (Billions)  Profits (Billions)  Assets (Billions)  \
# 1995                0.04                1.41               0.17
# 1996                3.52                1.41               5.72
# 1997               15.72                0.05              12.10
# ...

# %%
#Q6: Fetch records of all CEO
df.CEO
# Out:
# 0          Warren Edward Buffett
# 1                         Shu Gu
# 2       Amin bin Hasan Al-Nasser
# 3                    Jamie Dimon
# 4                      Wang Zuji
#                   ...
# 1994            Timoteo di Maulo
# 1995              Shan Min Huang
# 1996                   Sumit Deb
# 1997                      Wei Li
# 1998                     No Data
# Name: CEO, Length: 1999, dtype: object

# %%
#Q7: Print First starting records from column CEO of dataset  

df.CEO.head()
# Out:
# 0       Warren Edward Buffett
# 1                      Shu Gu
# 2    Amin bin Hasan Al-Nasser
# 3                 Jamie Dimon
# 4                   Wang Zuji
# Name: CEO, dtype: object

# %%
#Q7: Print first Organizations 2 records which are from India.
df.query('Country == "India"').head(2)
# Out:
#      2022 Ranking         Organization              Industry Country  \
# 53             54  Reliance Industries  Oil & Gas Operations   India
# 105           105  State Bank of India               Banking   India
#
#      Year Founded                      CEO  Revenue (Billions)  \
# 53           1973  Mukesh Dhirubhai Ambani               86.85
# 105          1955  Swaminathan Janakiraman               54.42
#
#      Profits (Billions)  Assets (Billions)  Market Value (Billions)  \
# 53                 7.81             192.59                   228.63
# 105                4.32             696.51                    58.39
#
#     Total Employees
# 53           236334
# 105          245652

# %%
#Q8 : Print all the columns name
df.columns
# Out:
# Index(['2022 Ranking', 'Organization', 'Industry', 'Country', 'Year Founded',
#        'CEO', 'Revenue (Billions)', 'Profits (Billions)', 'Assets (Billions)',
#        'Market Value (Billions)', 'Total Employees'],
#       dtype='object')

# %%
#Q9: Fetch the records of rows at 0,3,5.
df.loc[[0,3,5]]
# Out:
#    2022 Ranking        Organization                Industry        Country  \
# 0             1  Berkshire Hathaway  Diversified Financials  United States
# 3             4      JPMorgan Chase  Diversified Financials  United States
# 5             6              Amazon               Retailing  United States
#
#    Year Founded                    CEO  Revenue (Billions)  \
# 0          1939  Warren Edward Buffett              276.09
# 3          2000            Jamie Dimon              124.54
# 5          1994             Andy Jassy              469.82
#
#    Profits (Billions)  Assets (Billions)  Market Value (Billions)  \
# 0               89.80             958.78                   741.48
# 3               42.12            3954.69                   374.45
# 5               33.36             420.55                  1468.40
#
#   Total Employees
# 0          372000
# 3          271025
# 5         1608000
